# %% [markdown]
# # ⚙️ TMDB Data Extractor Notebook Overview
# This notebook extracts and processes TMDB data from JSON files, keeping only relevant fields.
#
# ## 📂 Steps in This Notebook
#
# ⓵ **Extract TMDB Data from JSON** → Keeps these keys:
#    `budget`, `genres`, `id`, `imdb_id`, `origin_country`, `original_language`, `original_title`,
#    `production_companies`, `production_countries`, `revenue`, `title`, `credits`, `keywords`, `actors_characters`.
#
# ⓶ **Parse JSON Files** → Functions to extract:
#    - **Genres, keywords, producers, credits, cast & characters**.
#
# ⓷ **Iterate Through Files** → Reads all JSON files in `subgenre_titles_data/` and extracts structured data.
#
# ⓸ **Save to CSV** → Exports final parsed data to `parsed_json_data.csv`.
#
# ---
#
# ### EXTRACT TMDB DATA FROM JSON FILES

# %%
TMDB_folder="subgenre_titles_data"
import json

# Load and inspect a sample TMDB JSON file
sample_tconst = "tt0065377"  # Change to any existing tconst in your dataset
file_path = f"{TMDB_folder}/{sample_tconst}.json"  # Update with your folder path

# Open and read the JSON file
with open(file_path, "r", encoding="utf-8") as f:
    tmdb_data = json.load(f)

# Print full JSON structure (or just keys for a quick view)
#print(json.dumps(tmdb_data, indent=4))  # Pretty-print entire JSON
print(tmdb_data.keys())  # Uncomment to print only top-level keys
keep_keys = ['budget', 'genres', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title',
            'production_companies', 'production_countries', 'revenue', 'title','credits', 'keywords', 
             'actors_characters']
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'release_dates', 'credits', 'keywords', 'actors_characters'])

# %%
tmdb_data["credits"]
# Out:
# {'cast': [{'adult': False,
#    'gender': 2,
#    'id': 13784,
#    'known_for_department': 'Acting',
#    'name': 'Burt Lancaster',
#    'original_name': 'Burt Lancaster',
#    'popularity': 0.059,
#    'profile_path': '/hQBgFAdk1BrSum7LN4B67m3gj0U.jpg',
#    'cast_id': 1,
#    'character': 'Mel Bakersfeld',
#    'credit_id': '52fe439f9251416c75017aa5',
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 69810,
#    'known_for_department': 'Acting',
#    'name': 'Dana Wynter',
#    'original_name': 'Dana Wynter',
#    'popularity': 0.037,
#    'profile_path': '/njOUHDQQvzxlXh6qdxJfa6NNUlt.jpg',
#    'cast_id': 18,
#    'character': 'Cindy Bakersfeld',
#    'credit_id': '52fe439f9251416c75017af9',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 4299,
#    'known_for_department': 'Acting',
#    'name': 'Dean Martin',
#    'original_name': 'Dean Martin',
#    'popularity': 0.048,
#    'profile_path': '/lMWkTDKPsDVS3DiMUNkTLLjm3f5.jpg',
#    'cast_id': 2,
#    'character': 'Vernon Demerest',
#    'credit_id': '52fe439f9251416c75017aa9',
#    'order': 2},
#   {'adult': False,
#    'gender': 1,
#    'id': 109701,
#    'known_for_department': 'Acting',
#    'name': 'Barbara Hale',
#    'original_name': 'Barbara Hale',
#    'popularity': 0.043,
#    'profile_path': '/xLE53ZfGifU5hNyjoE6z6FsOU01.jpg',
#    'cast_id': 20,
#    'character': 'Sarah Demerest',
#    'credit_id': '52fe439f9251416c75017b01',
#    'order': 3},
#   {'adult': False,
#    'gender': 1,
#    'id': 3830,
#    'known_for_department': 'Acting',
#    'name': 'Jean Seberg',
#    'original_name': 'Jean Seberg',
#    'popularity': 0.037,
#    'profile_path': '/mNW6MJ5YAiFWAnH9pCmi0PjKXc.jpg',
#    'cast_id': 3,
#    'character': 'Tanya Livingston',
#    'credit_id': '52fe439f9251416c75017aad',
#    'order': 4},
#   {'adult': False,
#    'gender': 1,
#    'id': 14061,
#    'known_for_department': 'Acting',
#    'name': 'Jacqueline Bisset',
#    'original_name': 'Jacqueline Bisset',
#    'popularity': 0.097,
#    'profile_path': '/ilIBKvLu4dPMl5WOczXvt7DsIss.jpg',
#    'cast_id': 4,
#    'character': 'Gwen Meighen',
#    'credit_id': '52fe439f9251416c75017ab1',
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 12950,
#    'known_for_department': 'Acting',
#    'name': 'George Kennedy',
#    'original_name': 'George Kennedy',
#    'popularity': 0.053,
#    'profile_path': '/fIVmcPEcPmh0Rbx4mYf9aneCmDe.jpg',
#    'cast_id': 5,
#    'character': 'Joe Patroni',
#    'credit_id': '52fe439f9251416c75017ab5',
#    'order': 6},
#   {'adult': False,
#    'gender': 1,
#    'id': 194646,
#    'known_for_department': 'Acting',
#    'name': 'Jodean Lawrence',
#    'original_name': 'Jodean Lawrence',
#    'popularity': 0.01,
#    'profile_path': None,
#    'cast_id': 84,
#    'character': 'Marie Patroni',
#    'credit_id': '60ebfdbae004a6005e788b33',
#    'order': 7},
#   {'adult': False,
#    'gender': 1,
#    'id': 47439,
#    'known_for_department': 'Acting',
#    'name': 'Helen Hayes',
#    'original_name': 'Helen Hayes',
#    'popularity': 0.042,
#    'profile_path': '/i1mqaJOQG9TBVBZjn8No70GeGhE.jpg',
#    'cast_id': 14,
#    'character': 'Ada Quonsett',
#    'credit_id': '52fe439f9251416c75017ae9',
#    'order': 8},
#   {'adult': False,
#    'gender': 2,
#    'id': 200507,
#    'known_for_department': 'Acting',
#    'name': 'John Findlater',
#    'original_name': 'John Findlater',
#    'popularity': 0.004,
#    'profile_path': '/u2StgNxF3rmRgxxksIuDgSzbHTR.jpg',
#    'cast_id': 22,
#    'character': 'Peter Coakley',
#    'credit_id': '52fe439f9251416c75017b09',
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 18803,
#    'known_for_department': 'Acting',
#    'name': 'Van Heflin',
#    'original_name': 'Van Heflin',
#    'popularity': 0.021,
#    'profile_path': '/hE9Hnv2RScUGCwkfFiRLrxqjeQQ.jpg',
#    'cast_id': 15,
#    'character': 'D. O. Guerrero',
#    'credit_id': '52fe439f9251416c75017aed',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 21151,
#    'known_for_department': 'Acting',
#    'name': 'Maureen Stapleton',
#    'original_name': 'Maureen Stapleton',
#    'popularity': 0.028,
#    'profile_path': '/rXwg71O6oU6x3sB5c4erlAu7mhy.jpg',
#    'cast_id': 16,
#    'character': 'Inez Guerrero',
#    'credit_id': '52fe439f9251416c75017af1',
#    'order': 11},
#   {'adult': False,
#    'gender': 2,
#    'id': 10411,
#    'known_for_department': 'Acting',
#    'name': 'Barry Nelson',
#    'original_name': 'Barry Nelson',
#    'popularity': 0.026,
#    'profile_path': '/fSrHmvOxZJbeKpNM0uWGvha1aK9.jpg',
#    'cast_id': 17,
#    'character': 'Anson Harris',
#    'credit_id': '52fe439f9251416c75017af5',
#    'order': 12},
#   {'adult': False,
#    'gender': 1,
#    'id': 161441,
#    'known_for_department': 'Acting',
#    'name': 'Eileen Wesson',
#    'original_name': 'Eileen Wesson',
#    'popularity': 0.008,
#    'profile_path': '/g6LWHk3ttZlZcmPKFkZtX4pLjYL.jpg',
#    'cast_id': 78,
#    'character': 'Judy Barton',
#    'credit_id': '60ebf45d5e1200005ef749a2',
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 78306,
#    'known_for_department': 'Acting',
#    'name': 'Robert Patten',
#    'original_name': 'Robert Patten',
#    'popularity': 0.017,
#    'profile_path': '/5LdkirLlW9HEgur3AtCyQsDXQYS.jpg',
#    'cast_id': 36,
#    'character': 'Captain Benson',
#    'credit_id': '54b2ac7492514174720047e8',
#    'order': 14},
#   {'adult': False,
#    'gender': 2,
#    'id': 78309,
#    'known_for_department': 'Acting',
#    'name': 'Paul Picerni',
#    'original_name': 'Paul Picerni',
#    'popularity': 0.022,
#    'profile_path': '/hTLiKlGFmYesMM6PMHdtIG7GHCD.jpg',
#    'cast_id': 35,
#    'character': 'Dr. Compagno',
#    'credit_id': '54b2a893c3a36820a7001561',
#    'order': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412543,
#    'known_for_department': 'Acting',
#    'name': 'Ilana Dowding',
#    'original_name': 'Ilana Dowding',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 79,
#    'character': 'Robbie Bakersfeld',
#    'credit_id': '60ebf92201b1ca0047110c44',
#    'order': 16},
#   {'adult': False,
#    'gender': 1,
#    'id': 153545,
#    'known_for_department': 'Acting',
#    'name': 'Lisa Gerritsen',
#    'original_name': 'Lisa Gerritsen',
#    'popularity': 0.011,
#    'profile_path': '/hBs7vnZhDjEVRvrUTJj0LYshCUq.jpg',
#    'cast_id': 30,
#    'character': 'Libby Bakersfeld',
#    'credit_id': '52fe43a09251416c75017b2f',
#    'order': 17},
#   {'adult': False,
#    'gender': 2,
#    'id': 117027,
#    'known_for_department': 'Acting',
#    'name': 'Clark Howat',
#    'original_name': 'Clark Howat',
#    'popularity': 0.014,
#    'profile_path': '/vCml23MUfvS0rz09Rd9DmUeBBJh.jpg',
#    'cast_id': 37,
#    'character': 'Bert Weatherby',
#    'credit_id': '54b37f16c3a3680939006655',
#    'order': 18},
#   {'adult': False,
#    'gender': 2,
#    'id': 152666,
#    'known_for_department': 'Acting',
#    'name': 'Gary Collins',
#    'original_name': 'Gary Collins',
#    'popularity': 0.016,
#    'profile_path': '/58U2ZmONQikSswsNXYoyyEkl23S.jpg',
#    'cast_id': 21,
#    'character': 'Cy Jordan',
#    'credit_id': '52fe439f9251416c75017b05',
#    'order': 19},
#   {'adult': False,
#    'gender': 2,
#    'id': 19411,
#    'known_for_department': 'Acting',
#    'name': 'Lloyd Nolan',
#    'original_name': 'Lloyd Nolan',
#    'popularity': 0.034,
#    'profile_path': '/tENzeS3MDaFbTdhD2xhyybAfKWP.jpg',
#    'cast_id': 19,
#    'character': 'Harry Standish',
#    'credit_id': '52fe439f9251416c75017afd',
#    'order': 20},
#   {'adult': False,
#    'gender': 1,
#    'id': 2640,
#    'known_for_department': 'Acting',
#    'name': 'Jessie Royce Landis',
#    'original_name': 'Jessie Royce Landis',
#    'popularity': 0.012,
#    'profile_path': '/9asCKCafalR0382PpkHZs5Lv8hK.jpg',
#    'cast_id': 23,
#    'character': 'Harriet DuBarry Mossman',
#    'credit_id': '52fe439f9251416c75017b0d',
#    'order': 21},
#   {'adult': False,
#    'gender': 1,
#    'id': 113655,
#    'known_for_department': 'Acting',
#    'name': 'Sandra Gould',
#    'original_name': 'Sandra Gould',
#    'popularity': 0.019,
#    'profile_path': '/l9gfVr8Oqu5VHSFVf9Fdfse5fuX.jpg',
#    'cast_id': 31,
#    'character': 'Millie Miles',
#    'credit_id': '52fe43a09251416c75017b33',
#    'order': 22},
#   {'adult': False,
#    'gender': 1,
#    'id': 153556,
#    'known_for_department': 'Acting',
#    'name': 'Janis Hansen',
#    'original_name': 'Janis Hansen',
#    'popularity': 0.008,
#    'profile_path': None,
#    'cast_id': 86,
#    'character': 'Katherine Grace',
#    'credit_id': '60ebfe575e12000046040c02',
#    'order': 23},
#   {'adult': False,
#    'gender': 2,
#    'id': 1216592,
#    'known_for_department': 'Acting',
#    'name': 'William Boyett',
#    'original_name': 'William Boyett',
#    'popularity': 0.028,
#    'profile_path': '/y3aYTWtDFScgy1hTJw7Pb1837R3.jpg',
#    'cast_id': 77,
#    'character': 'Jack Ingram',
#    'credit_id': '6037af0d11c066003f495ae2',
#    'order': 24},
#   {'adult': False,
#    'gender': 2,
#    'id': 14791,
#    'known_for_department': 'Acting',
#    'name': 'James Nolan',
#    'original_name': 'James Nolan',
#    'popularity': 0.019,
#    'profile_path': '/elakqIMwTQKP0zGmzu5T69sH0Zw.jpg',
#    'cast_id': 40,
#    'character': 'Steven Lonigan',
#    'credit_id': '54b386c7c3a36809400062b3',
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 105308,
#    'known_for_department': 'Acting',
#    'name': 'Peter Turgeon',
#    'original_name': 'Peter Turgeon',
#    'popularity': 0.012,
#    'profile_path': None,
#    'cast_id': 33,
#    'character': 'Marcus Rathbone',
#    'credit_id': '54b2a3fd9251416fe1003a39',
#    'order': 26},
#   {'adult': False,
#    'gender': 2,
#    'id': 1243622,
#    'known_for_department': 'Acting',
#    'name': 'Albert Reed Jr.',
#    'original_name': 'Albert Reed Jr.',
#    'popularity': 0.002,
#    'profile_path': None,
#    'cast_id': 83,
#    'character': 'Ned Ordway',
#    'credit_id': '60ebfd720e64af005cda5a64',
#    'order': 27},
#   {'adult': False,
#    'gender': 2,
#    'id': 165524,
#    'known_for_department': 'Acting',
#    'name': 'Dick Winslow',
#    'original_name': 'Dick Winslow',
#    'popularity': 0.01,
#    'profile_path': '/9Py3kHyImtkWn25CnJrTbbagqZQ.jpg',
#    'cast_id': 48,
#    'character': 'Mr. Schultz',
#    'credit_id': '54b3c92cc3a368094e006cf6',
#    'order': 28},
#   {'adult': False,
#    'gender': 1,
#    'id': 19967,
#    'known_for_department': 'Acting',
#    'name': 'Virginia Grey',
#    'original_name': 'Virginia Grey',
#    'popularity': 0.017,
#    'profile_path': '/ftyCI3XPJoGS75m3DFXOgOpw58z.jpg',
#    'cast_id': 28,
#    'character': 'Mrs. Schultz',
#    'credit_id': '52fe43a09251416c75017b27',
#    'order': 29},
#   {'adult': False,
#    'gender': 2,
#    'id': 13262,
#    'known_for_department': 'Acting',
#    'name': 'Lou Wagner',
#    'original_name': 'Lou Wagner',
#    'popularity': 0.038,
#    'profile_path': '/m3Ox9KLNVY4c4urgpV2DXpTWiMq.jpg',
#    'cast_id': 49,
#    'character': 'Schuyler Schultz',
#    'credit_id': '54b3c9fc925141144f0040fc',
#    'order': 30},
#   {'adult': False,
#    'gender': 2,
#    'id': 13786,
#    'known_for_department': 'Acting',
#    'name': 'Whit Bissell',
#    'original_name': 'Whit Bissell',
#    'popularity': 0.044,
#    'profile_path': '/ctpL0dPAv6n9ArbWRK1Cet0wvqk.jpg',
#    'cast_id': 27,
#    'character': 'Mr. Davidson',
#    'credit_id': '52fe43a09251416c75017b23',
#    'order': 31},
#   {'adult': False,
#    'gender': 1,
#    'id': 91261,
#    'known_for_department': 'Acting',
#    'name': 'Ena Hartman',
#    'original_name': 'Ena Hartman',
#    'popularity': 0.009,
#    'profile_path': '/7vrkesabHY2i30eZFdxYa6BVExR.jpg',
#    'cast_id': 42,
#    'character': 'Ruth',
#    'credit_id': '54b38b4c9251417369001f38',
#    'order': 32},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412669,
#    'known_for_department': 'Acting',
#    'name': 'Nancy Ann Nelson',
#    'original_name': 'Nancy Ann Nelson',
#    'popularity': 0.006,
#    'profile_path': '/yTOcLOmQSoxBPXj8vvHwhRkCoKt.jpg',
#    'cast_id': 85,
#    'character': 'Bunnie',
#    'credit_id': '60ebfe09bc2cb300750e0c40',
#    'order': 33},
#   {'adult': False,
#    'gender': 1,
#    'id': 84631,
#    'known_for_department': 'Acting',
#    'name': 'Mary Jackson',
#    'original_name': 'Mary Jackson',
#    'popularity': 0.021,
#    'profile_path': '/fLrCF0ZctgkrwxjOuwcBRaJYPnF.jpg',
#    'cast_id': 51,
#    'character': 'Felice',
#    'credit_id': '54b3cbed9251417369002551',
#    'order': 34},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412549,
#    'known_for_department': 'Acting',
#    'name': 'Patty Poulsen',
#    'original_name': 'Patty Poulsen',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 80,
#    'character': 'Joan',
#    'credit_id': '60ebfa3c1941860045219a3c',
#    'order': 35},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412558,
#    'known_for_department': 'Acting',
#    'name': 'Malila Saint Duval',
#    'original_name': 'Malila Saint Duval',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 81,
#    'character': 'Maria',
#    'credit_id': '60ebfcc0e004a6005e788ac1',
#    'order': 36},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412560,
#    'known_for_department': 'Acting',
#    'name': 'Sharon Harvey',
#    'original_name': 'Sharon Harvey',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 82,
#    'character': 'Sally',
#    'credit_id': '60ebfcdacae6320074aa8f32',
#    'order': 37},
#   {'adult': False,
#    'gender': 2,
#    'id': 1221564,
#    'known_for_department': 'Acting',
#    'name': 'Shelly Novack',
#    'original_name': 'Shelly Novack',
#    'popularity': 0.016,
#    'profile_path': '/rqIMVzUJZdRgSbRkwVccfFIxrO.jpg',
#    'cast_id': 52,
#    'character': 'Rollings',
#    'credit_id': '54b3cd51c3a36802870014bb',
#    'order': 38},
#   {'adult': False,
#    'gender': 2,
#    'id': 152719,
#    'known_for_department': 'Acting',
#    'name': 'Lew Brown',
#    'original_name': 'Lew Brown',
#    'popularity': 0.019,
#    'profile_path': None,
#    'cast_id': 38,
#    'character': 'Reynolds',
#    'credit_id': '54b3814392514107e0004f3c',
#    'order': 39},
#   {'adult': False,
#    'gender': 2,
#    'id': 3640,
#    'known_for_department': 'Acting',
#    'name': 'Larry Gates',
#    'original_name': 'Larry Gates',
#    'popularity': 0.019,
#    'profile_path': '/g9ovDZYmccbsuDNsdzaHEcjz3Zl.jpg',
#    'cast_id': 29,
#    'character': 'Ackerman',
#    'credit_id': '52fe43a09251416c75017b2b',
#    'order': 40},
#   {'adult': False,
#    'gender': 0,
#    'id': 1171678,
#    'known_for_department': 'Acting',
#    'name': 'Chuck Daniel',
#    'original_name': 'Chuck Daniel',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 87,
#    'character': 'Parks',
#    'credit_id': '60ebfec0194186007dfe46eb',
#    'order': 41},
#   {'adult': False,
#    'gender': 0,
#    'id': 1412679,
#    'known_for_department': 'Acting',
#    'name': 'Charles Brewer',
#    'original_name': 'Charles Brewer',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 54,
#    'character': 'Diller',
#    'credit_id': '54b3ceec92514114a2003d10',
#    'order': 42},
#   {'adult': False,
#    'gender': 2,
#    'id': 114553,
#    'known_for_department': 'Acting',
#    'name': 'Richard Mathews',
#    'original_name': 'Richard Mathews',
#    'popularity': 0.005,
#    'profile_path': '/t6r8h12ILdShXJR9R68bjxQuFz.jpg',
#    'cast_id': 99,
#    'character': 'Controller',
#    'credit_id': '644bbb6d336e010517735f79',
#    'order': 43},
#   {'adult': False,
#    'gender': 1,
#    'id': 153422,
#    'known_for_department': 'Acting',
#    'name': 'Cathleen Cordell',
#    'original_name': 'Cathleen Cordell',
#    'popularity': 0.013,
#    'profile_path': '/iHE9QmxiUwFg5ltl1vkGadvjUSy.jpg',
#    'cast_id': 88,
#    'character': 'Mrs. Donovan',
#    'credit_id': '641ee427253fab00d432e8d3',
#    'order': 44},
#   {'adult': False,
#    'gender': 2,
#    'id': 1176510,
#    'known_for_department': 'Acting',
#    'name': "William H. O'Brien",
#    'original_name': "William H. O'Brien",
#    'popularity': 0.01,
#    'profile_path': '/dHqtM4SNmq6W2WBnxyXgRdlgSfk.jpg',
#    'cast_id': 64,
#    'character': "Waiter at Men's Club",
#    'credit_id': '5b1c014ac3a36848f801e9db',
#    'order': 45},
#   {'adult': False,
#    'gender': 1,
#    'id': 1191818,
#    'known_for_department': 'Acting',
#    'name': 'Leoda Richards',
#    'original_name': 'Leoda Richards',
#    'popularity': 0.023,
#    'profile_path': '/5qi3y7BF4axQbnI6UvJZcS8PiqW.jpg',
#    'cast_id': 32,
#    'character': 'Woman on Dais',
#    'credit_id': '52fe43a09251416c75017b37',
#    'order': 46},
#   {'adult': False,
#    'gender': 2,
#    'id': 1240847,
#    'known_for_department': 'Acting',
#    'name': 'Ray Ballard',
#    'original_name': 'Ray Ballard',
#    'popularity': 0.01,
#    'profile_path': None,
#    'cast_id': 100,
#    'character': 'Gilbert Price (uncredited)',
#    'credit_id': '659e5260fc5f0600eec04ac6',
#    'order': 47},
#   {'adult': False,
#    'gender': 2,
#    'id': 41270,
#    'known_for_department': 'Directing',
#    'name': 'Chuck Bowman',
#    'original_name': 'Chuck Bowman',
#    'popularity': 0.019,
#    'profile_path': None,
#    'cast_id': 101,
#    'character': 'New York Dispatcher (uncredited)',
#    'credit_id': '659e53231d356301ffec1ab1',
#    'order': 48},
#   {'adult': False,
#    'gender': 1,
#    'id': 128201,
#    'known_for_department': 'Acting',
#    'name': 'Eve Brent',
#    'original_name': 'Eve Brent',
#    'popularity': 0.017,
#    'profile_path': '/3TctvAVPmpYs5tQSPOkPijc0RdV.jpg',
#    'cast_id': 102,
#    'character': 'Mrs. David Corman (uncredited)',
#    'credit_id': '659e53336728a80201abf5e5',
#    'order': 49},
#   {'adult': False,
#    'gender': 2,
#    'id': 134613,
#    'known_for_department': 'Acting',
#    'name': 'John Dennis',
#    'original_name': 'John Dennis',
#    'popularity': 0.029,
#    'profile_path': '/78XDuxSpAlTxpxMVbFi1EQpmjPW.jpg',
#    'cast_id': 103,
#    'character': 'Cab Driver (uncredited)',
#    'credit_id': '659e5349fc5f06014acb77d6',
#    'order': 50},
#   {'adult': False,
#    'gender': 0,
#    'id': 2420363,
#    'known_for_department': 'Crew',
#    'name': 'John Francis',
#    'original_name': 'John Francis',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 104,
#    'character': 'Maurice David (uncredited)',
#    'credit_id': '659e5418e8999b01a398cbe3',
#    'order': 51},
#   {'adult': False,
#    'gender': 2,
#    'id': 93628,
#    'known_for_department': 'Acting',
#    'name': 'Harry Harvey',
#    'original_name': 'Harry Harvey',
#    'popularity': 0.026,
#    'profile_path': '/gfBTGsPJGlbQ7ThZKPdwb0pYC5w.jpg',
#    'cast_id': 105,
#    'character': 'Dr. Avery Smith (uncredited)',
#    'credit_id': '659e547e6d97e601ff232cb7',
#    'order': 52},
#   {'adult': False,
#    'gender': 2,
#    'id': 151555,
#    'known_for_department': 'Acting',
#    'name': 'Gordon Jump',
#    'original_name': 'Gordon Jump',
#    'popularity': 0.02,
#    'profile_path': '/kzJyt1z3n73PlIsHZ4FnfAI0506.jpg',
#    'cast_id': 106,
#    'character': 'Man Inspecting Hole in Plane (uncredited)',
#    'credit_id': '659e548ffc5f0601a636622a',
#    'order': 53},
#   {'adult': False,
#    'gender': 1,
#    'id': 4075,
#    'known_for_department': 'Acting',
#    'name': 'Eve McVeagh',
#    'original_name': 'Eve McVeagh',
#    'popularity': 0.028,
#    'profile_path': '/hwV4caXk2r1W66OrWvlNS7MjV4F.jpg',
#    'cast_id': 107,
#    'character': 'Mrs. Henry Bron (uncredited)',
#    'credit_id': '659e54ba24b333025a50f716',
#    'order': 54},
#   {'adult': False,
#    'gender': 1,
#    'id': 1226675,
#    'known_for_department': 'Acting',
#    'name': 'Pat Priest',
#    'original_name': 'Pat Priest',
#    'popularity': 0.028,
#    'profile_path': '/naq1ZNHsRGlLmxeSOwNRxYxonOB.jpg',
#    'cast_id': 109,
#    'character': 'Mrs. Jerry Copeland (uncredited)',
#    'credit_id': '659e55237776f000ee2d9309',
#    'order': 55},
#   {'adult': False,
#    'gender': 2,
#    'id': 1574347,
#    'known_for_department': 'Acting',
#    'name': 'Don Ross',
#    'original_name': 'Don Ross',
#    'popularity': 0.021,
#    'profile_path': '/baLnPa7Kas06vkrwunNXp4L7QYA.jpg',
#    'cast_id': 110,
#    'character': 'John (uncredited)',
#    'credit_id': '659e5535d6590b01fdaf775c',
#    'order': 56},
#   {'adult': False,
#    'gender': 1,
#    'id': 75355,
#    'known_for_department': 'Acting',
#    'name': 'Marion Ross',
#    'original_name': 'Marion Ross',
#    'popularity': 0.08,
#    'profile_path': '/eZpOYvFoJnej8n7aKSi2LVvvlQu.jpg',
#    'cast_id': 111,
#    'character': 'Joan Myers (uncredited)',
#    'credit_id': '659e55456728a801a52f4d8f',
#    'order': 57},
#   {'adult': False,
#    'gender': 2,
#    'id': 1234318,
#    'known_for_department': 'Acting',
#    'name': 'Mark Russell',
#    'original_name': 'Mark Russell',
#    'popularity': 0.019,
#    'profile_path': '/trlBsJk0zZGfXT3R5yWidh2NcTE.jpg',
#    'cast_id': 112,
#    'character': 'Pfc. Bud Miller (uncredited)',
#    'credit_id': '659e55596728a8025b1f1be2',
#    'order': 58},
#   {'adult': False,
#    'gender': 2,
#    'id': 227977,
#    'known_for_department': 'Acting',
#    'name': 'Frank J. Scannell',
#    'original_name': 'Frank J. Scannell',
#    'popularity': 0.019,
#    'profile_path': '/oIyqrFdYMZYmz3tpREUQ8IO3bW4.jpg',
#    'cast_id': 113,
#    'character': 'Ted Fields (uncredited)',
#    'credit_id': '659e559691b53000ef1edb61',
#    'order': 59},
#   {'adult': False,
#    'gender': 1,
#    'id': 163335,
#    'known_for_department': 'Acting',
#    'name': 'Susan Seaforth Hayes',
#    'original_name': 'Susan Seaforth Hayes',
#    'popularity': 0.01,
#    'profile_path': '/1KPyaidPUZHUtoxxYOxQ7VGN51l.jpg',
#    'cast_id': 114,
#    'character': 'First Class Flight Attendant (uncredited)',
#    'credit_id': '659e55a36d97e6025a21c1c2',
#    'order': 60},
#   {'adult': False,
#    'gender': 1,
#    'id': 93672,
#    'known_for_department': 'Acting',
#    'name': 'Allison McKay',
#    'original_name': 'Allison McKay',
#    'popularity': 0.014,
#    'profile_path': '/9F9oogbkca5Pk5YpBdX4CvZrisQ.jpg',
#    'cast_id': 115,
#    'character': 'Mrs. Irwin Jansen (uncredited)',
#    'credit_id': '6688e08bad7b53bf91890842',
#    'order': 61},
#   {'adult': False,
#    'gender': 2,
#    'id': 3483517,
#    'known_for_department': 'Acting',
#    'name': 'John Nolan',
#    'original_name': 'John Nolan',
#    'popularity': 0.008,
#    'profile_path': None,
#    'cast_id': 116,
#    'character': 'Richard Ross (uncredited)',
#    'credit_id': '6688e0c3d9eb7335101d103a',
#    'order': 62},
#   {'adult': False,
#    'gender': 2,
#    'id': 165042,
#    'known_for_department': 'Acting',
#    'name': 'Ron Stokes',
#    'original_name': 'Ron Stokes',
#    'popularity': 0.006,
#    'profile_path': None,
#    'cast_id': 117,
#    'character': 'Taxi Driver (uncredited)',
#    'credit_id': '6688e1195ddd15ac6c1d14ae',
#    'order': 63},
#   {'adult': False,
#    'gender': 2,
#    'id': 91371,
#    'known_for_department': 'Acting',
#    'name': 'Quinn K. Redeker',
#    'original_name': 'Quinn K. Redeker',
#    'popularity': 0.016,
#    'profile_path': '/3oVdl0QPKxqCTmrGNffNk66gK0s.jpg',
#    'cast_id': 118,
#    'character': 'John Reindel (uncredited)',
#    'credit_id': '670f35727a22bf3607f27a74',
#    'order': 64}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 24939,
#    'known_for_department': 'Directing',
#    'name': 'George Seaton',
#    'original_name': 'George Seaton',
#    'popularity': 0.021,
#    'profile_path': '/ynH63JLcuHEf1xnNSBXULzLDgkJ.jpg',
#    'credit_id': '52fe439f9251416c75017abb',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 8503,
#    'known_for_department': 'Sound',
#    'name': 'Alfred Newman',
#    'original_name': 'Alfred Newman',
#    'popularity': 0.012,
#    'profile_path': '/7U2GMZwkQmlNiXpFwGwabQLqUI1.jpg',
#    'credit_id': '52fe439f9251416c75017ad9',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 9103,
#    'known_for_department': 'Camera',
#    'name': 'Ernest Laszlo',
#    'original_name': 'Ernest Laszlo',
#    'popularity': 0.006,
#    'profile_path': None,
#    'credit_id': '52fe439f9251416c75017adf',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 41408,
#    'known_for_department': 'Production',
#    'name': 'Ross Hunter',
#    'original_name': 'Ross Hunter',
#    'popularity': 0.008,
#    'profile_path': '/eEug7jTemeUXUvAYcIeRp3UmMUL.jpg',
#    'credit_id': '52fe439f9251416c75017ad3',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 52096,
#    'known_for_department': 'Writing',
#    'name': 'Arthur Hailey',
#    'original_name': 'Arthur Hailey',
#    'popularity': 0.005,
#    'profile_path': None,
#    'credit_id': '52fe439f9251416c75017ac1',
#    'department': 'Writing',
#    'job': 'Novel'},
#   {'adult': False,
#    'gender': 2,
#    'id': 30259,
#    'known_for_department': 'Editing',
#    'name': 'Stuart Gilmore',
#    'original_name': 'Stuart Gilmore',
#    'popularity': 0.004,
#    'profile_path': None,
#    'credit_id': '52fe439f9251416c75017ae5',
#    'department': 'Editing',
#    'job': 'Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 24939,
#    'known_for_department': 'Directing',
#    'name': 'George Seaton',
#    'original_name': 'George Seaton',
#    'popularity': 0.021,
#    'profile_path': '/ynH63JLcuHEf1xnNSBXULzLDgkJ.jpg',
#    'credit_id': '52fe439f9251416c75017acd',
#    'department': 'Writing',
#    'job': 'Screenplay'},
#   {'adult': False,
#    'gender': 1,
#    'id': 4350,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Edith Head',
#    'original_name': 'Edith Head',
#    'popularity': 0.019,
#    'profile_path': '/l6LmpdKnU67FaoNBLi8VRRoO6wX.jpg',
#    'credit_id': '5983b0e9c3a368444f002a06',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Design'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2118,
#    'known_for_department': 'Art',
#    'name': 'Mickey S. Michaels',
#    'original_name': 'Mickey S. Michaels',
#    'popularity': 0.003,
#    'profile_path': None,
#    'credit_id': '5983b0dc92514158b50027b3',
#    'department': 'Art',
#    'job': 'Set Decoration'},
#   {'adult': False,
#    'gender': 2,
#    'id': 40170,
#    'known_for_department': 'Art',
#    'name': 'E. Preston Ames',
#    'original_name': 'E. Preston Ames',
#    'popularity': 0.007,
#    'profile_path': None,
#    'credit_id': '5983b0d092514158ae0028d8',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1534172,
#    'known_for_department': 'Art',
#    'name': 'Jack D. Moore',
#    'original_name': 'Jack D. Moore',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '5983b0e2c3a36843ec0029f5',
#    'department': 'Art',
#    'job': 'Set Decoration'},
#   {'adult': False,
#    'gender': 2,
#    'id': 41409,
#    'known_for_department': 'Art',
#    'name': 'Jacques Mapes',
#    'original_name': 'Jacques Mapes',
#    'popularity': 0.005,
#    'profile_path': None,
#    'credit_id': '5983b87992514158a70032e9',
#    'department': 'Production',
#    'job': 'Associate Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 12346,
#    'known_for_department': 'Art',
#    'name': 'Alexander Golitzen',
#    'original_name': 'Alexander Golitzen',
#    'popularity': 0.029,
#    'profile_path': None,
#    'credit_id': '5983b0d692514158ae0028eb',
#    'department': 'Art',
#    'job': 'Art Direction'},
#   {'adult': False,
#    'gender': 0,
#    'id': 3708030,
#    'known_for_department': 'Camera',
#    'name': 'Everett Lehman',
#    'original_name': 'Everett Lehman',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '6424d7fa6905fb00bd08ffbf',
#    'department': 'Lighting',
#    'job': 'Gaffer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 69934,
#    'known_for_department': 'Acting',
#    'name': 'Nick Cravat',
#    'original_name': 'Nick Cravat',
#    'popularity': 0.012,
#    'profile_path': '/bODGLcc1Jim10yaIQTZ4Lf8Y16h.jpg',
#    'credit_id': '6424d7ed8de0ae00d5f16cde',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1782794,
#    'known_for_department': 'Crew',
#    'name': 'Bud Walls',
#    'original_name': 'Bud Walls',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '6424d7e38de0ae00978b66db',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1088497,
#    'known_for_department': 'Crew',
#    'name': 'Carol Daniels',
#    'original_name': 'Carol Daniels',
#    'popularity': 0.012,
#    'profile_path': None,
#    'credit_id': '6424d7c3a3e4ba00d3ac603c',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 24793,
#    'known_for_department': 'Camera',
#    'name': 'Loyal Griggs',
#    'original_name': 'Loyal Griggs',
#    'popularity': 0.002,
#    'profile_path': None,
#    'credit_id': '6424d8096905fb00e0549f6d',
#    'department': 'Camera',
#    'job': 'Additional Photography'},
#   {'adult': False,
#    'gender': 2,
#    'id': 100350,
#    'known_for_department': 'Acting',
#    'name': 'Don Nagel',
#    'original_name': 'Don Nagel',
#    'popularity': 0.002,
#    'profile_path': None,
#    'credit_id': '6424d7d937b3a900b6bbe874',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 120048,
#    'known_for_department': 'Acting',
#    'name': 'Joe Gray',
#    'original_name': 'Joe Gray',
#    'popularity': 0.008,
#    'profile_path': None,
#    'credit_id': '6424d7d0a3e4ba007791f49a',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1762450,
#    'known_for_department': 'Crew',
#    'name': 'Donna Garrett',
#    'original_name': 'Donna Garrett',
#    'popularity': 0.008,
#    'profile_path': '/gf2qgBOMOSAYlp834vsh4RF0LBG.jpg',
#    'credit_id': '6424d7c7a3e4ba00d3ac6042',
#    'department': 'Crew',
#    'job': 'Stunt Double'},
#   {'adult': False,
#    'gender': 2,
#    'id': 3644,
#    'known_for_department': 'Acting',
#    'name': 'Dean Smith',
#    'original_name': 'Dean Smith',
#    'popularity': 0.015,
#    'profile_path': '/rGKyvasZZMeZqxrab99xFAYLMbe.jpg',
#    'credit_id': '6424d7d56905fb00bd08ff9b',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 2,
#    'id': 26738,
#    'known_for_department': 'Crew',
#    'name': 'Bob Yerkes',
#    'original_name': 'Bob Yerkes',
#    'popularity': 0.01,
#    'profile_path': '/uhgqPGZH2i2MzVBdAqPpasF3gGx.jpg',
#    'credit_id': '6424d7e86905fb01260811b4',
#    'department': 'Crew',
#    'job': 'Stunts'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2735190,
#    'known_for_department': 'Production',
#    'name': 'Raymond Gosnell',
#    'original_name': 'Raymond Gosnell',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '5f751a4a40d0fe003534e835',
#    'department': 'Production',
#    'job': 'Unit Production Manager'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1455417,
#    'known_for_department': 'Directing',
#    'name': 'Betty A. Griffin',
#    'original_name': 'Betty A. Griffin',
#    'popularity': 0.006,
#    'profile_path': None,
#    'credit_id': '5f751bba3ff2df00385155c4',
#    'department': 'Directing',
#    'job': 'Script Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 2119487,
#    'known_for_department': 'Sound',
#    'name': 'Arnold Schwarzwald',
#    'original_name': 'Arnold Schwarzwald',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '5f751b19bc8abc003a6fd011',
#    'department': 'Sound',
#    'job': 'Music Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 14495,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Larry Germain',
#    'original_name': 'Larry Germain',
#    'popularity': 0.005,
#    'profile_path': None,
#    'credit_id': '5f751badfea0d700350f8ace',
#    'department': 'Costume & Make-Up',
#    'job': 'Hairstylist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 14499,
#    'known_for_department': 'Sound',
#    'name': 'Ronald Pierce',
#    'original_name': 'Ronald Pierce',
#    'popularity': 0.002,
#    'profile_path': None,
#    'credit_id': '5f751afcbc8abc00376ee555',
#    'department': 'Sound',
#    'job': 'Sound'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2442423,
#    'known_for_department': 'Sound',
#    'name': 'David H. Moriarty',
#    'original_name': 'David H. Moriarty',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '5f751af440d0fe003534ea0e',
#    'department': 'Sound',
#    'job': 'Sound'},
#   {'adult': False,
#    'gender': 2,
#    'id': 14498,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Bud Westmore',
#    'original_name': 'Bud Westmore',
#    'popularity': 0.008,
#    'profile_path': '/cujaF4TgLnpronQ3aMCnbLSSOW7.jpg',
#    'credit_id': '5f751ba0bc8abc003a6fd967',
#    'department': 'Costume & Make-Up',
#    'job': 'Makeup Artist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 2798561,
#    'known_for_department': 'Production',
#    'name': 'Donald Roberts',
#    'original_name': 'Donald Roberts',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '5f751aac21621b0035309808',
#    'department': 'Directing',
#    'job': 'Assistant Director'},
#   {'adult': False,
#    'gender': 0,
#    'id': 7310,
#    'known_for_department': 'Sound',
#    'name': 'Waldon O. Watson',
#    'original_name': 'Waldon O. Watson',
#    'popularity': 0.003,
#    'profile_path': None,
#    'credit_id': '5f751ae5bc8abc003a6fce40',
#    'department': 'Sound',
#    'job': 'Sound'}]}

# %%
# parse data

import os
import json
import pandas as pd

# Path where TMDB JSON files are stored
TMDB_JSON_FOLDER = "subgenre_titles_data"

# TMDB Fields to extract
TOP_LEVEL_KEYS = [
    'budget', 'id', 'imdb_id', 'origin_country',
    'original_language', 'original_title', 'revenue', 'title'
]

def extract_keywords(data):
    """Extract 'name' values from the 'keywords' field."""
    return [kw['name'] for kw in data.get('keywords', {}).get('keywords', [])]

def extract_genres(data):
    """Extract genre names from the 'genres' field."""
    return [genre['name'] for genre in data.get('genres', [])]

def extract_producers(data):
    """Extract names of production companies from the TMDB JSON."""
    return [company['name'] for company in data.get('production_companies', [])]

def extract_credits(data):
    """Extract relevant cast and crew members from 'credits'."""
    extracted_data = {
        'cast': [],
        'crew': []
    }

    if 'credits' in data:
        # Extract cast details with additional fields
        if 'cast' in data['credits']:
            extracted_data['cast'] = [
                {
                    'name': member.get('name', 'Not Found'),
                    'order': member.get('order', 'Not Found'),
                    'character': member.get('character', 'Not Found'),
                    'gender': member.get('gender', 'Not Found'),
                    'id': member.get('id', 'Not Found'),
                    'popularity': member.get('popularity', 'Not Found'),
                    'credit_id': member.get('credit_id', 'Not Found'),
                    'adult': member.get('adult', 'Not Found')
                }
                for member in data['credits']['cast']
            ]

        # Extract specific crew members with additional fields
        if 'crew' in data['credits']:
            extracted_data['crew'] = [
                {
                    'name': member.get('name', 'Not Found'),
                    'job': member.get('job', 'Not Found'),
                    'gender': member.get('gender', 'Not Found'),
                    'id': member.get('id', 'Not Found'),
                    'popularity': member.get('popularity', 'Not Found'),
                    'credit_id': member.get('credit_id', 'Not Found')
                }
                for member in data['credits']['crew']
                if member.get('job') in ['Director', 'Producer', 'Director of Photography']
            ]

    return extracted_data

def parse_tmdb_json(tconst):
    """Parse a single TMDB JSON file and extract necessary fields."""
    file_path = os.path.join(TMDB_JSON_FOLDER, f"{tconst}.json")

    if not os.path.exists(file_path):
        return {key: "Not Found" for key in TOP_LEVEL_KEYS + ["keywords", "cast", "crew"]}

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Extract data
    parsed_data = {key: data.get(key, "Not Found") for key in TOP_LEVEL_KEYS}
    parsed_data["keywords"] = extract_keywords(data)
    parsed_data["production_companies"] = extract_producers(data)
    credits_data = extract_credits(data)
    parsed_data["genres"] = extract_genres(data)
    parsed_data["cast"] = credits_data["cast"]
    parsed_data["crew"] = credits_data["crew"]

    return parsed_data

# Example usage
# parse_tmdb_json(sample_tconst)

# %% [markdown]
# ### ITERATE THROUGH FILES

# %%
import os
import pandas as pd

def parse_all_files(folder_path):
    """Parse all TMDB JSON files in a folder and return a DataFrame."""
    tmdb_data_list = []
    json_files = [f for f in os.listdir(folder_path) if f.endswith(".json")]

    for i, filename in enumerate(json_files):
        tconst = filename.replace(".json", "")  # Extract IMDb ID from filename
        
        if i % 500 == 0:
            print(f"Processing {i}/{len(json_files)}...")

        tmdb_data = parse_tmdb_json(tconst)  # Use the parsing function
        tmdb_data["tconst"] = tconst  # Store the tconst for merging
        tmdb_data_list.append(tmdb_data)

    # Convert extracted TMDB data to DataFrame
    df_tmdb = pd.DataFrame(tmdb_data_list)
    df_tmdb = df_tmdb.drop(columns=["imdb_id", "id"])


    return df_tmdb

# Run parsing on all JSON files in the folder
df_tmdb = parse_all_files("subgenre_titles_data/")
# Out:
# Processing 0/11072...
# Processing 500/11072...
# Processing 1000/11072...
# Processing 1500/11072...
# Processing 2000/11072...
# Processing 2500/11072...
# Processing 3000/11072...
# Processing 3500/11072...
# Processing 4000/11072...
# Processing 4500/11072...
# Processing 5000/11072...
# Processing 5500/11072...
# Processing 6000/11072...
# Processing 6500/11072...
# Processing 7000/11072...
# Processing 7500/11072...
# Processing 8000/11072...
# Processing 8500/11072...
# Processing 9000/11072...
# Processing 9500/11072...
# Processing 10000/11072...
# Processing 10500/11072...
# Processing 11000/11072...

# %% [markdown]
# ### SAVE AS JSON

# %%
df_tmdb.to_csv("parsed_json_data.csv", index=False)

df_tmdb.head()
# Out:
#      budget origin_country original_language          original_title  \
# 0  48000000           [US]                en          Kate & Leopold
# 1         0           [FR]                fr              Le Boucher
# 2         0           [US]                en   The Honeymoon Killers
# 3         0           [GB]                en        I Start Counting
# 4         0           [XC]                cs  Kladivo na čarodějnice
#
#     revenue                  title  \
# 0  76019048         Kate & Leopold
# 1         0            The Butcher
# 2         0  The Honeymoon Killers
# 3         0       I Start Counting
# 4         0            Witchhammer
#
#                                             keywords  \
# 0  [new york city, time travel, duke, fish out of...
# 1  [vietnam veteran, province, butcher, murder, f...
# 2  [nurse, widow, alabama, lonely hearts ad, base...
# 3  [exploitation, stalker, serial killer, crying,...
# 4  [witch, based on novel or book, witch burning,...
#
#                                 production_companies  \
# 0                         [Konrad Pictures, Miramax]
# 1    [Les Films La Boétie, Euro International Films]
# 2  [Roxanne Company, American International Pictu...
# 3                [Triumvirate Films, United Artists]
# 4                         [Filmové studio Barrandov]
#
#                               genres  \
# 0         [Romance, Comedy, Fantasy]
# 1           [Thriller, Crime, Drama]
# 2  [Crime, Drama, Romance, Thriller]
# 3                  [Thriller, Drama]
# 4                  [Drama, Thriller]
#
#                                                 cast  \
# 0  [{'name': 'Meg Ryan', 'order': 0, 'character':...
# 1  [{'name': 'Stéphane Audran', 'order': 0, 'char...
# 2  [{'name': 'Shirley Stoler', 'order': 0, 'chara...
# 3  [{'name': 'Jenny Agutter', 'order': 0, 'charac...
# 4  [{'name': 'Elo Romančík', 'order': 0, 'charact...
#
#                                                 crew     tconst
# 0  [{'name': 'James Mangold', 'job': 'Director', ...  tt0035423
# 1  [{'name': 'Claude Chabrol', 'job': 'Director',...  tt0064106
# 2  [{'name': 'Leonard Kastle', 'job': 'Director',...  tt0064437
# 3  [{'name': 'David Greene', 'job': 'Director', '...  tt0064462
# 4  [{'name': 'Otakar Vávra', 'job': 'Director', '...  tt0064546
