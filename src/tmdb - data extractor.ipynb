# %% [markdown]
# # ⚙️ TMDB Data Extractor Notebook Overview
# This notebook extracts and processes TMDB data from JSON files, keeping only relevant fields.
#
# ## 📂 Steps in This Notebook
#
# ⓵ **Extract TMDB Data from JSON** → Keeps these keys:
#    `budget`, `genres`, `id`, `imdb_id`, `origin_country`, `original_language`, `original_title`,
#    `production_companies`, `production_countries`, `revenue`, `title`, `credits`, `keywords`, `actors_characters`, `belongs_to_collection`.
#
# ⓶ **Parse JSON Files** → Functions to extract:
#    - **Genres, keywords, producers, credits, cast & characters**.
#
# ⓷ **Iterate Through Files** → Reads all JSON files in `subgenre_titles_data/` and extracts structured data.
#
# ⓸ **Save to CSV** → Exports final parsed data to `parsed_json_data.csv`.
#
# ---
#
# ### EXTRACT TMDB DATA FROM JSON FILES

# %%
TMDB_folder="../data/IMDb-subgenre_titles_data"
import json

# Load and inspect a sample TMDB JSON file
sample_tconst = "tt0065377"  # Change to any existing tconst in your dataset
file_path = f"{TMDB_folder}/{sample_tconst}.json"  # Update with your folder path

# Open and read the JSON file
with open(file_path, "r", encoding="utf-8") as f:
    tmdb_data = json.load(f)

# Print full JSON structure (or just keys for a quick view)
#print(json.dumps(tmdb_data, indent=4))  # Pretty-print entire JSON
print(tmdb_data.keys())  # Uncomment to print only top-level keys
keep_keys = ['budget', 'genres', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title',
             'production_companies', 'production_countries', 'revenue', 'title','credits', 'keywords', 
             'actors_characters', 'belongs_to_collection']
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count', 'release_dates', 'credits', 'keywords', 'actors_characters'])

# %%
import os
sample_tconst = "tt0065377"
TMDB_JSON_FOLDER = "subgenre_titles_data"
file_path = os.path.join(TMDB_JSON_FOLDER, f"{sample_tconst}.json")
print(os.path.exists(file_path))  # Should return True
# Out:
# False

# %%
# parse data
TMDB_JSON_FOLDER = TMDB_folder

import os
import json
import pandas as pd

# Path where TMDB JSON files are stored
# TMDB Fields to extract
TOP_LEVEL_KEYS = [
    'budget', 'id', 'imdb_id', 'origin_country',
    'original_language', 'original_title', 'revenue', 'title'
]

def extract_keywords(data):
    """Extract 'name' values from the 'keywords' field."""
    return [kw['name'] for kw in data.get('keywords', {}).get('keywords', [])]

def extract_genres(data):
    """Extract genre names from the 'genres' field."""
    return [genre['name'] for genre in data.get('genres', [])]

def extract_producers(data):
    """Extract names of production companies from the TMDB JSON."""
    return [company['name'] for company in data.get('production_companies', [])]

def extract_credits(data):
    """Extract relevant cast and crew members from 'credits'."""
    extracted_data = {
        'cast': [],
        'crew': []
    }

    if 'credits' in data:
        # Extract cast details with additional fields
        if 'cast' in data['credits']:
            extracted_data['cast'] = [
                {
                    'name': member.get('name', 'Not Found'),
                    'order': member.get('order', 'Not Found'),
                    'character': member.get('character', 'Not Found'),
                    'gender': member.get('gender', 'Not Found'),
                    'id': member.get('id', 'Not Found'),
                    'popularity': member.get('popularity', 'Not Found'),
                    'credit_id': member.get('credit_id', 'Not Found'),
                    'adult': member.get('adult', 'Not Found')
                }
                for member in data['credits']['cast']
            ]

        # Extract specific crew members with additional fields
        if 'crew' in data['credits']:
            extracted_data['crew'] = [
                {
                    'name': member.get('name', 'Not Found'),
                    'job': member.get('job', 'Not Found'),
                    'gender': member.get('gender', 'Not Found'),
                    'id': member.get('id', 'Not Found'),
                    'popularity': member.get('popularity', 'Not Found'),
                    'credit_id': member.get('credit_id', 'Not Found')
                }
                for member in data['credits']['crew']
                if member.get('job') in ['Director', 'Producer', 'Director of Photography']
            ]

    return extracted_data

def parse_tmdb_json(tconst):
    """Parse a single TMDB JSON file and extract necessary fields."""
    file_path = os.path.join(TMDB_JSON_FOLDER, f"{tconst}.json")

    if not os.path.exists(file_path):
        return {
            **{key: "Not Found" for key in TOP_LEVEL_KEYS},
            "keywords": "Not Found",
            "genres": "Not Found",
            "production_companies": "Not Found",
            "cast": "Not Found",
            "crew": "Not Found",
            "franchise": "Not Found"
        }

    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Extract data
    parsed_data = {key: data.get(key, "Not Found") for key in TOP_LEVEL_KEYS}
    parsed_data["keywords"] = extract_keywords(data)
    parsed_data["production_companies"] = extract_producers(data)
    credits_data = extract_credits(data)
    parsed_data["genres"] = extract_genres(data)
    parsed_data["cast"] = credits_data["cast"]
    parsed_data["crew"] = credits_data["crew"]

    # ✅ Add franchise flag
    parsed_data["franchise"] = data.get("belongs_to_collection") is not None

    return parsed_data


# Example usage
parse_tmdb_json(sample_tconst)
# Out:
# {'budget': 10000000,
#  'id': 10671,
#  'imdb_id': 'tt0065377',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Airport',
#  'revenue': 100489151,
#  'title': 'Airport',
#  'keywords': ['airplane',
#   'airport',
#   'based on novel or book',
#   'panic',
#   'bomb',
#   'stowaway',
#   'snowstorm',
#   'landing',
#   'deception',
#   'blizzard',
#   'disaster movie',
#   'suicide bomber',
#   'snowplow'],
#  'production_companies': ['Ross Hunter Productions'],
#  'genres': ['Action', 'Drama', 'Thriller'],
#  'cast': [{'name': 'Burt Lancaster',
#    'order': 0,
#    'character': 'Mel Bakersfeld',
#    'gender': 2,
#    'id': 13784,
#    'popularity': 0.059,
#    'credit_id': '52fe439f9251416c75017aa5',
#    'adult': False},
#   {'name': 'Dana Wynter',
#    'order': 1,
#    'character': 'Cindy Bakersfeld',
#    'gender': 1,
#    'id': 69810,
#    'popularity': 0.037,
#    'credit_id': '52fe439f9251416c75017af9',
#    'adult': False},
#   {'name': 'Dean Martin',
#    'order': 2,
#    'character': 'Vernon Demerest',
#    'gender': 2,
#    'id': 4299,
#    'popularity': 0.048,
#    'credit_id': '52fe439f9251416c75017aa9',
#    'adult': False},
#   {'name': 'Barbara Hale',
#    'order': 3,
#    'character': 'Sarah Demerest',
#    'gender': 1,
#    'id': 109701,
#    'popularity': 0.043,
#    'credit_id': '52fe439f9251416c75017b01',
#    'adult': False},
#   {'name': 'Jean Seberg',
#    'order': 4,
#    'character': 'Tanya Livingston',
#    'gender': 1,
#    'id': 3830,
#    'popularity': 0.037,
#    'credit_id': '52fe439f9251416c75017aad',
#    'adult': False},
#   {'name': 'Jacqueline Bisset',
#    'order': 5,
#    'character': 'Gwen Meighen',
#    'gender': 1,
#    'id': 14061,
#    'popularity': 0.097,
#    'credit_id': '52fe439f9251416c75017ab1',
#    'adult': False},
#   {'name': 'George Kennedy',
#    'order': 6,
#    'character': 'Joe Patroni',
#    'gender': 2,
#    'id': 12950,
#    'popularity': 0.053,
#    'credit_id': '52fe439f9251416c75017ab5',
#    'adult': False},
#   {'name': 'Jodean Lawrence',
#    'order': 7,
#    'character': 'Marie Patroni',
#    'gender': 1,
#    'id': 194646,
#    'popularity': 0.01,
#    'credit_id': '60ebfdbae004a6005e788b33',
#    'adult': False},
#   {'name': 'Helen Hayes',
#    'order': 8,
#    'character': 'Ada Quonsett',
#    'gender': 1,
#    'id': 47439,
#    'popularity': 0.042,
#    'credit_id': '52fe439f9251416c75017ae9',
#    'adult': False},
#   {'name': 'John Findlater',
#    'order': 9,
#    'character': 'Peter Coakley',
#    'gender': 2,
#    'id': 200507,
#    'popularity': 0.004,
#    'credit_id': '52fe439f9251416c75017b09',
#    'adult': False},
#   {'name': 'Van Heflin',
#    'order': 10,
#    'character': 'D. O. Guerrero',
#    'gender': 2,
#    'id': 18803,
#    'popularity': 0.021,
#    'credit_id': '52fe439f9251416c75017aed',
#    'adult': False},
#   {'name': 'Maureen Stapleton',
#    'order': 11,
#    'character': 'Inez Guerrero',
#    'gender': 1,
#    'id': 21151,
#    'popularity': 0.028,
#    'credit_id': '52fe439f9251416c75017af1',
#    'adult': False},
#   {'name': 'Barry Nelson',
#    'order': 12,
#    'character': 'Anson Harris',
#    'gender': 2,
#    'id': 10411,
#    'popularity': 0.026,
#    'credit_id': '52fe439f9251416c75017af5',
#    'adult': False},
#   {'name': 'Eileen Wesson',
#    'order': 13,
#    'character': 'Judy Barton',
#    'gender': 1,
#    'id': 161441,
#    'popularity': 0.008,
#    'credit_id': '60ebf45d5e1200005ef749a2',
#    'adult': False},
#   {'name': 'Robert Patten',
#    'order': 14,
#    'character': 'Captain Benson',
#    'gender': 2,
#    'id': 78306,
#    'popularity': 0.017,
#    'credit_id': '54b2ac7492514174720047e8',
#    'adult': False},
#   {'name': 'Paul Picerni',
#    'order': 15,
#    'character': 'Dr. Compagno',
#    'gender': 2,
#    'id': 78309,
#    'popularity': 0.022,
#    'credit_id': '54b2a893c3a36820a7001561',
#    'adult': False},
#   {'name': 'Ilana Dowding',
#    'order': 16,
#    'character': 'Robbie Bakersfeld',
#    'gender': 0,
#    'id': 1412543,
#    'popularity': 0.001,
#    'credit_id': '60ebf92201b1ca0047110c44',
#    'adult': False},
#   {'name': 'Lisa Gerritsen',
#    'order': 17,
#    'character': 'Libby Bakersfeld',
#    'gender': 1,
#    'id': 153545,
#    'popularity': 0.011,
#    'credit_id': '52fe43a09251416c75017b2f',
#    'adult': False},
#   {'name': 'Clark Howat',
#    'order': 18,
#    'character': 'Bert Weatherby',
#    'gender': 2,
#    'id': 117027,
#    'popularity': 0.014,
#    'credit_id': '54b37f16c3a3680939006655',
#    'adult': False},
#   {'name': 'Gary Collins',
#    'order': 19,
#    'character': 'Cy Jordan',
#    'gender': 2,
#    'id': 152666,
#    'popularity': 0.016,
#    'credit_id': '52fe439f9251416c75017b05',
#    'adult': False},
#   {'name': 'Lloyd Nolan',
#    'order': 20,
#    'character': 'Harry Standish',
#    'gender': 2,
#    'id': 19411,
#    'popularity': 0.034,
#    'credit_id': '52fe439f9251416c75017afd',
#    'adult': False},
#   {'name': 'Jessie Royce Landis',
#    'order': 21,
#    'character': 'Harriet DuBarry Mossman',
#    'gender': 1,
#    'id': 2640,
#    'popularity': 0.012,
#    'credit_id': '52fe439f9251416c75017b0d',
#    'adult': False},
#   {'name': 'Sandra Gould',
#    'order': 22,
#    'character': 'Millie Miles',
#    'gender': 1,
#    'id': 113655,
#    'popularity': 0.019,
#    'credit_id': '52fe43a09251416c75017b33',
#    'adult': False},
#   {'name': 'Janis Hansen',
#    'order': 23,
#    'character': 'Katherine Grace',
#    'gender': 1,
#    'id': 153556,
#    'popularity': 0.008,
#    'credit_id': '60ebfe575e12000046040c02',
#    'adult': False},
#   {'name': 'William Boyett',
#    'order': 24,
#    'character': 'Jack Ingram',
#    'gender': 2,
#    'id': 1216592,
#    'popularity': 0.028,
#    'credit_id': '6037af0d11c066003f495ae2',
#    'adult': False},
#   {'name': 'James Nolan',
#    'order': 25,
#    'character': 'Steven Lonigan',
#    'gender': 2,
#    'id': 14791,
#    'popularity': 0.019,
#    'credit_id': '54b386c7c3a36809400062b3',
#    'adult': False},
#   {'name': 'Peter Turgeon',
#    'order': 26,
#    'character': 'Marcus Rathbone',
#    'gender': 2,
#    'id': 105308,
#    'popularity': 0.012,
#    'credit_id': '54b2a3fd9251416fe1003a39',
#    'adult': False},
#   {'name': 'Albert Reed Jr.',
#    'order': 27,
#    'character': 'Ned Ordway',
#    'gender': 2,
#    'id': 1243622,
#    'popularity': 0.002,
#    'credit_id': '60ebfd720e64af005cda5a64',
#    'adult': False},
#   {'name': 'Dick Winslow',
#    'order': 28,
#    'character': 'Mr. Schultz',
#    'gender': 2,
#    'id': 165524,
#    'popularity': 0.01,
#    'credit_id': '54b3c92cc3a368094e006cf6',
#    'adult': False},
#   {'name': 'Virginia Grey',
#    'order': 29,
#    'character': 'Mrs. Schultz',
#    'gender': 1,
#    'id': 19967,
#    'popularity': 0.017,
#    'credit_id': '52fe43a09251416c75017b27',
#    'adult': False},
#   {'name': 'Lou Wagner',
#    'order': 30,
#    'character': 'Schuyler Schultz',
#    'gender': 2,
#    'id': 13262,
#    'popularity': 0.038,
#    'credit_id': '54b3c9fc925141144f0040fc',
#    'adult': False},
#   {'name': 'Whit Bissell',
#    'order': 31,
#    'character': 'Mr. Davidson',
#    'gender': 2,
#    'id': 13786,
#    'popularity': 0.044,
#    'credit_id': '52fe43a09251416c75017b23',
#    'adult': False},
#   {'name': 'Ena Hartman',
#    'order': 32,
#    'character': 'Ruth',
#    'gender': 1,
#    'id': 91261,
#    'popularity': 0.009,
#    'credit_id': '54b38b4c9251417369001f38',
#    'adult': False},
#   {'name': 'Nancy Ann Nelson',
#    'order': 33,
#    'character': 'Bunnie',
#    'gender': 0,
#    'id': 1412669,
#    'popularity': 0.006,
#    'credit_id': '60ebfe09bc2cb300750e0c40',
#    'adult': False},
#   {'name': 'Mary Jackson',
#    'order': 34,
#    'character': 'Felice',
#    'gender': 1,
#    'id': 84631,
#    'popularity': 0.021,
#    'credit_id': '54b3cbed9251417369002551',
#    'adult': False},
#   {'name': 'Patty Poulsen',
#    'order': 35,
#    'character': 'Joan',
#    'gender': 0,
#    'id': 1412549,
#    'popularity': 0.001,
#    'credit_id': '60ebfa3c1941860045219a3c',
#    'adult': False},
#   {'name': 'Malila Saint Duval',
#    'order': 36,
#    'character': 'Maria',
#    'gender': 0,
#    'id': 1412558,
#    'popularity': 0.001,
#    'credit_id': '60ebfcc0e004a6005e788ac1',
#    'adult': False},
#   {'name': 'Sharon Harvey',
#    'order': 37,
#    'character': 'Sally',
#    'gender': 0,
#    'id': 1412560,
#    'popularity': 0.001,
#    'credit_id': '60ebfcdacae6320074aa8f32',
#    'adult': False},
#   {'name': 'Shelly Novack',
#    'order': 38,
#    'character': 'Rollings',
#    'gender': 2,
#    'id': 1221564,
#    'popularity': 0.016,
#    'credit_id': '54b3cd51c3a36802870014bb',
#    'adult': False},
#   {'name': 'Lew Brown',
#    'order': 39,
#    'character': 'Reynolds',
#    'gender': 2,
#    'id': 152719,
#    'popularity': 0.019,
#    'credit_id': '54b3814392514107e0004f3c',
#    'adult': False},
#   {'name': 'Larry Gates',
#    'order': 40,
#    'character': 'Ackerman',
#    'gender': 2,
#    'id': 3640,
#    'popularity': 0.019,
#    'credit_id': '52fe43a09251416c75017b2b',
#    'adult': False},
#   {'name': 'Chuck Daniel',
#    'order': 41,
#    'character': 'Parks',
#    'gender': 0,
#    'id': 1171678,
#    'popularity': 0.001,
#    'credit_id': '60ebfec0194186007dfe46eb',
#    'adult': False},
#   {'name': 'Charles Brewer',
#    'order': 42,
#    'character': 'Diller',
#    'gender': 0,
#    'id': 1412679,
#    'popularity': 0.001,
#    'credit_id': '54b3ceec92514114a2003d10',
#    'adult': False},
#   {'name': 'Richard Mathews',
#    'order': 43,
#    'character': 'Controller',
#    'gender': 2,
#    'id': 114553,
#    'popularity': 0.005,
#    'credit_id': '644bbb6d336e010517735f79',
#    'adult': False},
#   {'name': 'Cathleen Cordell',
#    'order': 44,
#    'character': 'Mrs. Donovan',
#    'gender': 1,
#    'id': 153422,
#    'popularity': 0.013,
#    'credit_id': '641ee427253fab00d432e8d3',
#    'adult': False},
#   {'name': "William H. O'Brien",
#    'order': 45,
#    'character': "Waiter at Men's Club",
#    'gender': 2,
#    'id': 1176510,
#    'popularity': 0.01,
#    'credit_id': '5b1c014ac3a36848f801e9db',
#    'adult': False},
#   {'name': 'Leoda Richards',
#    'order': 46,
#    'character': 'Woman on Dais',
#    'gender': 1,
#    'id': 1191818,
#    'popularity': 0.023,
#    'credit_id': '52fe43a09251416c75017b37',
#    'adult': False},
#   {'name': 'Ray Ballard',
#    'order': 47,
#    'character': 'Gilbert Price (uncredited)',
#    'gender': 2,
#    'id': 1240847,
#    'popularity': 0.01,
#    'credit_id': '659e5260fc5f0600eec04ac6',
#    'adult': False},
#   {'name': 'Chuck Bowman',
#    'order': 48,
#    'character': 'New York Dispatcher (uncredited)',
#    'gender': 2,
#    'id': 41270,
#    'popularity': 0.019,
#    'credit_id': '659e53231d356301ffec1ab1',
#    'adult': False},
#   {'name': 'Eve Brent',
#    'order': 49,
#    'character': 'Mrs. David Corman (uncredited)',
#    'gender': 1,
#    'id': 128201,
#    'popularity': 0.017,
#    'credit_id': '659e53336728a80201abf5e5',
#    'adult': False},
#   {'name': 'John Dennis',
#    'order': 50,
#    'character': 'Cab Driver (uncredited)',
#    'gender': 2,
#    'id': 134613,
#    'popularity': 0.029,
#    'credit_id': '659e5349fc5f06014acb77d6',
#    'adult': False},
#   {'name': 'John Francis',
#    'order': 51,
#    'character': 'Maurice David (uncredited)',
#    'gender': 0,
#    'id': 2420363,
#    'popularity': 0.001,
#    'credit_id': '659e5418e8999b01a398cbe3',
#    'adult': False},
#   {'name': 'Harry Harvey',
#    'order': 52,
#    'character': 'Dr. Avery Smith (uncredited)',
#    'gender': 2,
#    'id': 93628,
#    'popularity': 0.026,
#    'credit_id': '659e547e6d97e601ff232cb7',
#    'adult': False},
#   {'name': 'Gordon Jump',
#    'order': 53,
#    'character': 'Man Inspecting Hole in Plane (uncredited)',
#    'gender': 2,
#    'id': 151555,
#    'popularity': 0.02,
#    'credit_id': '659e548ffc5f0601a636622a',
#    'adult': False},
#   {'name': 'Eve McVeagh',
#    'order': 54,
#    'character': 'Mrs. Henry Bron (uncredited)',
#    'gender': 1,
#    'id': 4075,
#    'popularity': 0.028,
#    'credit_id': '659e54ba24b333025a50f716',
#    'adult': False},
#   {'name': 'Pat Priest',
#    'order': 55,
#    'character': 'Mrs. Jerry Copeland (uncredited)',
#    'gender': 1,
#    'id': 1226675,
#    'popularity': 0.028,
#    'credit_id': '659e55237776f000ee2d9309',
#    'adult': False},
#   {'name': 'Don Ross',
#    'order': 56,
#    'character': 'John (uncredited)',
#    'gender': 2,
#    'id': 1574347,
#    'popularity': 0.021,
#    'credit_id': '659e5535d6590b01fdaf775c',
#    'adult': False},
#   {'name': 'Marion Ross',
#    'order': 57,
#    'character': 'Joan Myers (uncredited)',
#    'gender': 1,
#    'id': 75355,
#    'popularity': 0.08,
#    'credit_id': '659e55456728a801a52f4d8f',
#    'adult': False},
#   {'name': 'Mark Russell',
#    'order': 58,
#    'character': 'Pfc. Bud Miller (uncredited)',
#    'gender': 2,
#    'id': 1234318,
#    'popularity': 0.019,
#    'credit_id': '659e55596728a8025b1f1be2',
#    'adult': False},
#   {'name': 'Frank J. Scannell',
#    'order': 59,
#    'character': 'Ted Fields (uncredited)',
#    'gender': 2,
#    'id': 227977,
#    'popularity': 0.019,
#    'credit_id': '659e559691b53000ef1edb61',
#    'adult': False},
#   {'name': 'Susan Seaforth Hayes',
#    'order': 60,
#    'character': 'First Class Flight Attendant (uncredited)',
#    'gender': 1,
#    'id': 163335,
#    'popularity': 0.01,
#    'credit_id': '659e55a36d97e6025a21c1c2',
#    'adult': False},
#   {'name': 'Allison McKay',
#    'order': 61,
#    'character': 'Mrs. Irwin Jansen (uncredited)',
#    'gender': 1,
#    'id': 93672,
#    'popularity': 0.014,
#    'credit_id': '6688e08bad7b53bf91890842',
#    'adult': False},
#   {'name': 'John Nolan',
#    'order': 62,
#    'character': 'Richard Ross (uncredited)',
#    'gender': 2,
#    'id': 3483517,
#    'popularity': 0.008,
#    'credit_id': '6688e0c3d9eb7335101d103a',
#    'adult': False},
#   {'name': 'Ron Stokes',
#    'order': 63,
#    'character': 'Taxi Driver (uncredited)',
#    'gender': 2,
#    'id': 165042,
#    'popularity': 0.006,
#    'credit_id': '6688e1195ddd15ac6c1d14ae',
#    'adult': False},
#   {'name': 'Quinn K. Redeker',
#    'order': 64,
#    'character': 'John Reindel (uncredited)',
#    'gender': 2,
#    'id': 91371,
#    'popularity': 0.016,
#    'credit_id': '670f35727a22bf3607f27a74',
#    'adult': False}],
#  'crew': [{'name': 'George Seaton',
#    'job': 'Director',
#    'gender': 2,
#    'id': 24939,
#    'popularity': 0.021,
#    'credit_id': '52fe439f9251416c75017abb'},
#   {'name': 'Ernest Laszlo',
#    'job': 'Director of Photography',
#    'gender': 2,
#    'id': 9103,
#    'popularity': 0.006,
#    'credit_id': '52fe439f9251416c75017adf'},
#   {'name': 'Ross Hunter',
#    'job': 'Producer',
#    'gender': 2,
#    'id': 41408,
#    'popularity': 0.008,
#    'credit_id': '52fe439f9251416c75017ad3'}],
#  'franchise': True}

# %% [markdown]
# ### ITERATE THROUGH FILES

# %%
import os
import pandas as pd

def parse_all_files(folder_path):
    """Parse all TMDB JSON files in a folder and return a DataFrame."""
    tmdb_data_list = []
    json_files = [f for f in os.listdir(folder_path) if f.endswith(".json")]

    for i, filename in enumerate(json_files):
        tconst = filename.replace(".json", "")  # Extract IMDb ID from filename
        
        if i % 500 == 0:
            print(f"Processing {i}/{len(json_files)}...")

        tmdb_data = parse_tmdb_json(tconst)  # Use the parsing function
        tmdb_data["tconst"] = tconst  # Store the tconst for merging
        tmdb_data_list.append(tmdb_data)

    # Convert extracted TMDB data to DataFrame
    df_tmdb = pd.DataFrame(tmdb_data_list)
    df_tmdb = df_tmdb.drop(columns=["imdb_id", "id"])


    return df_tmdb

# Run parsing on all JSON files in the folder
df_tmdb = parse_all_files(TMDB_JSON_FOLDER)
# Out:
# Processing 0/11072...
# Processing 500/11072...
# Processing 1000/11072...
# Processing 1500/11072...
# Processing 2000/11072...
# Processing 2500/11072...
# Processing 3000/11072...
# Processing 3500/11072...
# Processing 4000/11072...
# Processing 4500/11072...
# Processing 5000/11072...
# Processing 5500/11072...
# Processing 6000/11072...
# Processing 6500/11072...
# Processing 7000/11072...
# Processing 7500/11072...
# Processing 8000/11072...
# Processing 8500/11072...
# Processing 9000/11072...
# Processing 9500/11072...
# Processing 10000/11072...
# Processing 10500/11072...
# Processing 11000/11072...

# %% [markdown]
# ### SAVE AS JSON

# %%
df_tmdb.to_csv("../data/cache/parsed_json_data.csv", index=False)

df_tmdb.head()
# Out:
#      budget origin_country original_language          original_title  \
# 0  48000000           [US]                en          Kate & Leopold
# 1         0           [FR]                fr              Le Boucher
# 2         0           [US]                en   The Honeymoon Killers
# 3         0           [GB]                en        I Start Counting
# 4         0           [XC]                cs  Kladivo na čarodějnice
#
#     revenue                  title  \
# 0  76019048         Kate & Leopold
# 1         0            The Butcher
# 2         0  The Honeymoon Killers
# 3         0       I Start Counting
# 4         0            Witchhammer
#
#                                             keywords  \
# 0  [new york city, time travel, duke, fish out of...
# 1  [vietnam veteran, province, butcher, murder, f...
# 2  [nurse, widow, alabama, lonely hearts ad, base...
# 3  [exploitation, stalker, serial killer, crying,...
# 4  [witch, based on novel or book, witch burning,...
#
#                                 production_companies  \
# 0                         [Konrad Pictures, Miramax]
# 1    [Les Films La Boétie, Euro International Films]
# 2  [Roxanne Company, American International Pictu...
# 3                [Triumvirate Films, United Artists]
# 4                         [Filmové studio Barrandov]
#
#                               genres  \
# 0         [Romance, Comedy, Fantasy]
# 1           [Thriller, Crime, Drama]
# 2  [Crime, Drama, Romance, Thriller]
# 3                  [Thriller, Drama]
# 4                  [Drama, Thriller]
#
#                                                 cast  \
# 0  [{'name': 'Meg Ryan', 'order': 0, 'character':...
# 1  [{'name': 'Stéphane Audran', 'order': 0, 'char...
# 2  [{'name': 'Shirley Stoler', 'order': 0, 'chara...
# 3  [{'name': 'Jenny Agutter', 'order': 0, 'charac...
# 4  [{'name': 'Elo Romančík', 'order': 0, 'charact...
#
#                                                 crew  franchise     tconst
# 0  [{'name': 'James Mangold', 'job': 'Director', ...      False  tt0035423
# 1  [{'name': 'Claude Chabrol', 'job': 'Director',...      False  tt0064106
# 2  [{'name': 'Leonard Kastle', 'job': 'Director',...      False  tt0064437
# 3  [{'name': 'David Greene', 'job': 'Director', '...      False  tt0064462
# 4  [{'name': 'Otakar Vávra', 'job': 'Director', '...      False  tt0064546
